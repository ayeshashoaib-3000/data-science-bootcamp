# %% [markdown]
# <a href="https://colab.research.google.com/github/ayeshashoaib-3000/data-science-bootcamp/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9abd4d9-61e8-409f-a7a6-d1eae209ad72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9abd4d9-61e8-409f-a7a6-d1eae209ad72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('students.csv')

# %%
print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (20, 9)
#    Student_ID    Name  Age Gender  Study_Hours  Attendance  Assignments  \
# 0         101     Ali   19      M          3.5          82            7
# 1         102    Sara   20      F          5.0          91            9
# 2         103   Ahmed   19      M          2.0          70            6
# 3         104  Ayesha   20      F          4.5          88            8
# 4         105   Bilal   21      M          1.5          65            5
#
#    Previous_Score  Final_Score
# 0              68           72
# 1              78           85
# 2              55           60
# 3              74           81
# 4              48           52

# %%
df.info()

print("\nMissing Values:")
print(df.isnull().sum())

print("\nStatistical Summary:")
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      20 non-null     int64
#  1   Name            20 non-null     object
#  2   Age             20 non-null     int64
#  3   Gender          20 non-null     object
#  4   Study_Hours     20 non-null     float64
#  5   Attendance      20 non-null     int64
#  6   Assignments     20 non-null     int64
#  7   Previous_Score  20 non-null     int64
#  8   Final_Score     20 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 1.5+ KB
#
# Missing Values:
# Student_ID        0
# Name              0
# Age               0
# Gender            0
# Study_Hours       0
# Attendance        0
# Assignments       0
# Previous_Score    0
# Final_Score       0
# dtype: int64
#
# Statistical Summary:
# ...

# %%
print("Duplicate rows before cleaning:", df.duplicated().sum())

df = df.drop_duplicates()

print("Duplicate rows after cleaning:", df.duplicated().sum())
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Duplicate rows before cleaning: 0
# Duplicate rows after cleaning: 0
#
# Missing values:
# Student_ID        0
# Name              0
# Age               0
# Gender            0
# Study_Hours       0
# Attendance        0
# Assignments       0
# Previous_Score    0
# Final_Score       0
# dtype: int64

# %%
def performance_category(score):
    if score >= 85:
        return "Excellent"
    elif score >= 70:
        return "Good"
    elif score >= 50:
        return "Average"
    else:
        return "Needs Improvement"

df["Performance"] = df["Final_Score"].apply(performance_category)

df[["Name", "Final_Score", "Performance"]].head(10)
# Out:
#      Name  Final_Score Performance
# 0     Ali           72        Good
# 1    Sara           85   Excellent
# 2   Ahmed           60     Average
# 3  Ayesha           81        Good
# 4   Bilal           52     Average
# 5    Hina           92   Excellent
# 6   Usman           67     Average
# 7  Zainab           76        Good
# 8   Hamza           63     Average
# 9  Maryam           89   Excellent

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="Performance", order=["Needs Improvement", "Average", "Good", "Excellent"])
plt.title("Distribution of Student Performance")
plt.xlabel("Performance Category")
plt.ylabel("Number of Students")
plt.show()

print(df["Performance"].value_counts())
# Out:
# Performance
# Good                 7
# Average              7
# Excellent            5
# Needs Improvement    1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="Study_Hours", y="Final_Score", hue="Gender", s=80)
plt.title("Study Hours vs Final Score")
plt.xlabel("Study Hours")
plt.ylabel("Final Score")
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="Attendance", y="Final_Score", hue="Performance", s=80)
plt.title("Attendance vs Final Score")
plt.xlabel("Attendance (%)")
plt.ylabel("Final Score")
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.regplot(data=df, x="Previous_Score", y="Final_Score", scatter_kws={"s":70})
plt.title("Previous Score vs Final Score")
plt.xlabel("Previous Score")
plt.ylabel("Final Score")
plt.grid(True, alpha=0.3)
plt.show()

# %%
gender_average = df.groupby("Gender")["Final_Score"].mean()

print(gender_average)

plt.figure(figsize=(6, 4))
gender_average.plot(kind="bar")
plt.title("Average Final Score by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Final Score")
plt.xticks(rotation=0)
plt.show()
# Out:
# Gender
# F    84.0
# M    61.8
# Name: Final_Score, dtype: float64

# %%
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(9, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

print("Correlation with Final Score:")
print(numeric_df.corr()["Final_Score"].sort_values(ascending=False))
# Out:
# Correlation with Final Score:
# Final_Score       1.000000
# Previous_Score    0.995763
# Attendance        0.994719
# Study_Hours       0.985494
# Assignments       0.984295
# Student_ID        0.013987
# Age              -0.057752
# Name: Final_Score, dtype: float64

# %%
top_students = df.sort_values(by="Final_Score", ascending=False).head(5)

print("Top 5 Students:")
display(top_students[["Student_ID", "Name", "Study_Hours", "Attendance", "Previous_Score", "Final_Score", "Performance"]])
# Out:
# Top 5 Students:
#     Student_ID    Name  Study_Hours  Attendance  Previous_Score  Final_Score  \
# 17         118    Noor          6.5          97              88           94
# 5          106    Hina          6.0          95              85           92
# 9          110  Maryam          5.5          93              82           89
# 13         114    Iqra          5.0          90              79           86
# 1          102    Sara          5.0          91              78           85
#
#    Performance
# 17   Excellent
# 5    Excellent
# 9    Excellent
# 13   Excellent
# 1    Excellent

# %%
features = ["Study_Hours", "Attendance", "Assignments", "Previous_Score"]

X = df[features]
y = df["Final_Score"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

print("Training data size:", X_train.shape)
print("Testing data size:", X_test.shape)
# Out:
# Training data size: (16, 4)
# Testing data size: (4, 4)

# %%
model = LinearRegression()

model.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
y_pred = model.predict(X_test)

results = pd.DataFrame({
    "Actual Score": y_test.values,
    "Predicted Score": np.round(y_pred, 2)
})

display(results)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Model Evaluation")
print("MAE :", round(mae, 2))
print("MSE :", round(mse, 2))
print("RMSE:", round(rmse, 2))
print("R² Score:", round(r2, 2))
# Out:
#    Actual Score  Predicted Score
# 0            72            73.91
# 1            94            94.79
# 2            80            80.07
# 3            85            85.06
# Model Evaluation
# MAE : 0.71
# MSE : 1.07
# RMSE: 1.03
# R² Score: 0.98

# %%
plt.figure(figsize=(7, 5))
plt.scatter(y_test, y_pred, s=80)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.xlabel("Actual Final Score")
plt.ylabel("Predicted Final Score")
plt.title("Actual vs Predicted Final Scores")
plt.grid(True, alpha=0.3)
plt.show()

# %%
coefficients = pd.DataFrame({
    "Feature": features,
    "Coefficient": model.coef_
}).sort_values(by="Coefficient", ascending=False)

display(coefficients)

plt.figure(figsize=(8, 5))
sns.barplot(data=coefficients, x="Coefficient", y="Feature")
plt.title("Linear Regression Feature Coefficients")
plt.show()
# Out:
#           Feature  Coefficient
# 0     Study_Hours     1.250749
# 1      Attendance     0.543341
# 3  Previous_Score     0.479834
# 2     Assignments    -0.204248

# %%
new_student = pd.DataFrame({
    "Study_Hours": [4.0],
    "Attendance": [85],
    "Assignments": [8],
    "Previous_Score": [72]
})

predicted_score = model.predict(new_student)[0]

print("Predicted Final Score:", round(predicted_score, 2))
# Out:
# Predicted Final Score: 77.88
